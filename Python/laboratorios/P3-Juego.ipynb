# %% [markdown]
# # PRACTICA 3
#
# ## JUEGO DE ADIVINANZAS
# ## Autores: Antonia Arizabaleta, Claudia Delgado, Jone Gonzalez, Nora Palmero, Paula Rascón, Cristina Ruiz
# #### Escribe un programa que coja un número entero del 1 al 100, y los jugadores tienen que tratar de adivinar el número.
#
# #### Las reglas son las siguientes:
#
# 1. Si un jugador escoje un número menor que 1 o mayor que 100, el programa dice "FUERA DE LÍMITES"
# 2. En el primer turno del jugador, si está en un rango de 10 del número dice "¡CALIENTE!". Si está fuera de ese rango dice "¡FRIO!"
# 3. En todas las rondas siguientes, si el jugador se acerca más que la vez anterior, dice "¡MAS CALIENTE!". Si está más lejos que la anterior vez dice "¡MAS FRIO!"
# 4. Cuando el jugador acierte el número, les dirá que han acertado y cuántos intentos les ha llevado

# %%
##### PISTAS
1. Trata obtener un número aleatorio entre el 1 y el 100
2. Haz una introducción de tu juego y explica las reglas
3. Crea una lista que almacene los intentos. 
4. Haz un bucle que evalúe un número. Prueba que funcione primero. While podría ir bien
5. Modifica ese bucle para que compare nuestro número con el intento. Si se acierta usa break, si no puedes usar continue y tienes que seguir preguntando al jugador por nuevos intentos

# %%
import random

print("Bienvenidos a FRIO o CALIENTE")
print("He pensado un número del 1 al 100. Intenta adivinarlo...")
print("Pero antes, estas son las reglas de nuestro juego:")
print("- Si tu número es menor que 1 o mayor que 100 → 'FUERA DE LÍMITES'")
print("- Primer intento: dentro de 10 → '¡CALIENTE!', si no → '¡FRÍO!'")
print("- Intentos siguientes: más cerca → '¡MÁS CALIENTE!', más lejos → '¡MÁS FRÍO!'")
print("- El juego termina cuando aciertas. ¡Suerte!\n")

# Número aleatorio entre 1 y 100 (import random nos deja acceder a la libreria random)
numero_secreto = random.randint(1, 100)

# Lista para guardar los intentos del jugador en orden y luego imprimir en cuantos intentos acertó el numero secreto
intentos = []

# while true nos permite crear el bucle para este juego
while True:
    try:
        intento = int(input("Introduce tu número: "))
    except ValueError:
        print("Debes ingresar un número entero.")
        continue
    
    # Verificar límites, ya que el numero tiene que estar dentro del rango 1-100
    if intento < 1 or intento > 100:
        print("Debes ingresar un número dentro del rango 1-100")
        continue
    
    # Guardamos el intento en la lista previamente creada.  
    intentos.append(intento)
    
    # Si acierta
    if intento == numero_secreto:
        print(f"¡Acertaste! El número era {numero_secreto}.")
        print(f"Lo lograste en {len(intentos)} intentos.")
        break
    
    # Primer intento
    if len(intentos) == 1:
        if abs(numero_secreto - intento) <= 10:
            print("¡CALIENTE!")
        else:
            print("¡FRÍO!")
    else:
        # Comparar con el intento anterior
        if abs(numero_secreto - intento) < abs(numero_secreto - intentos[-2]):
            print("¡MÁS CALIENTE!")
        else:
            print("¡MÁS FRÍO!")
# Out:
# Bienvenidos a FRIO o CALIENTE
# He pensado un número del 1 al 100. Intenta adivinarlo...
# Estas son las reglas de nuestro juego:
# - Si tu número es menor que 1 o mayor que 100 → 'FUERA DE LÍMITES'
# - Primer intento: dentro de 10 → '¡CALIENTE!', si no → '¡FRÍO!'
# - Intentos siguientes: más cerca → '¡MÁS CALIENTE!', más lejos → '¡MÁS FRÍO!'
# - El juego termina cuando aciertas. ¡Suerte!
# Introduce tu número:  2.5
# Debes ingresar un número entero.
# Introduce tu número:  2.01
# Debes ingresar un número entero.
# Introduce tu número:  2.0
# Debes ingresar un número entero.
# Introduce tu número:  140
# FUERA DE LÍMITES
# Introduce tu número:  102
# FUERA DE LÍMITES
# Introduce tu número:  -20
# FUERA DE LÍMITES
# Introduce tu número:  105.5
# Debes ingresar un número entero.
# Introduce tu número:  105
# FUERA DE LÍMITES

# %% [markdown]
# # PRIMER NOTEBOOK

# %% [markdown]
# **Este es mi primer notebook y voy a hacer lo siguiente.**
#
# Una lista enumerada:
# 1. Primero
# 2. Segundo
# 3. Tercero
#
# Una lista por puntos:
# - Primero
# - Segundo
# - Tercero
#
# Mi primer código:

# %%
mi_primera_frase= "hello world"
# como cuando lo ejecutas no sale nada, teno que usar la función print() 
print(mi_primera_frase)
# Out:
# hello world

# %%
# a ver si así lo entiendes mejor:
numeros = (10,20,30,40,50)

# %%
media= sum(numeros)/len(numeros)

# %%
print(media)
# Out:
# 30.0

# %% [markdown]
# #finalizamos con una bonita imagen
# ![Miimagen](llama.jpg)
